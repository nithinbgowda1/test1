# %%
import numpy as np
import pandas as pd
import math

score = pd.read_csv('test_score.csv')
score
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 1000
    n = len(x)
    learning_rate = 0.001
    for i in range(iterations):
        y_predicted = m_curr*x + b_curr
        cost = (1/n) * sum([val**2 for val in (y - y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print('m {}, b {}, iteration {}, cost {}'.format(m_curr,b_curr,iterations, cost))
        
x = score.area
y = score.price

gradient_descent(x,y)
# Out:
# m 8584901.768322447, b 1567.0274166491045, iteration 1000, cost 724377351794.1938
# m -441344266657.36414, b -76230796.78192486, iteration 1000, cost 1.8944486480851407e+21
# m 2.268966560234075e+16, b 3919061011149.2334, iteration 1000, cost 5.0070744566377297e+30
# m -1.1664837720684967e+21, b -2.0148031932589523e+17, iteration 1000, cost 1.3233821164672618e+40
# m 5.996934526698294e+25, b 1.0358174818609566e+22, iteration 1000, cost 3.497731542345388e+49
# m -3.0830453520783566e+30, b -5.325174485123395e+26, iteration 1000, cost 9.244590651547091e+58
# m 1.585004572028432e+35, b 2.737691127404219e+31, iteration 1000, cost 2.4433680881456494e+68
# m -8.148564832682307e+39, b -1.407456737803796e+36, iteration 1000, cost 6.457882062273281e+77
# m 4.189206138847387e+44, b 7.235785107239457e+40, iteration 1000, cost 1.7068341414691115e+87
# m -2.1536857635800127e+49, b -3.7199428381611087e+45, iteration 1000, cost 4.511204692795327e+96
# m 1.1072175048238176e+54, b 1.9124358330295264e+50, iteration 1000, cost 1.1923225160461126e+106
# m -5.692244540589103e+58, b -9.831900581739368e+54, iteration 1000, cost 3.1513377890854057e+115
# m 2.92640314741251e+63, b 5.054615029675318e+59, iteration 1000, cost 8.32906342643756e+124
# m -1.5044742579347364e+68, b -2.5985955498443126e+64, iteration 1000, cost 2.2013919866633394e+134
# m 7.734555626040738e+72, b 1.3359472070624586e+69, iteration 1000, cost 5.818333263693629e+143
# m -3.9763625344072556e+77, b -6.86815206839291e+73, iteration 1000, cost 1.5377998181375634e+153
# m 2.0442621101338515e+82, b 3.5309413863960006e+78, iteration 1000, cost 4.064442811174878e+162
# m -1.0509624157174237e+87, b -1.815269515003824e+83, iteration 1000, cost 1.0742422498994846e+172
# m 5.403035128300073e+91, b 9.332365087673125e+87, iteration 1000, cost 2.8392487361275713e+181
# m -2.777719560762462e+96, b -4.7978020569268895e+92, iteration 1000, cost 7.504204369504461e+190
# m 1.4280354976462943e+101, b 2.466567087892539e+97, iteration 1000, cost 1.9833797054390803e+200
# m -7.341581242917597e+105, b -1.2680709055703723e+102, iteration 1000, cost 5.242121432531532e+209
# m 3.774333007491494e+110, b 6.51919759023445e+106, iteration 1000, cost 1.3855056113586162e+219
# m -1.9403980123740321e+115, b -3.3515426490604967e+111, iteration 1000, cost 3.661925470084324e+228
# m 9.975655139469249e+119, b 1.7230399865925028e+116, iteration 1000, cost 9.6785592483475e+237
# m -5.128519758679124e+124, b -8.858209804458032e+120, iteration 1000, cost 2.5580670575913135e+247
# m 2.6365902336677562e+129, b 4.554037140773215e+125, iteration 1000, cost 6.761034264734331e+256
# m -1.355480409041578e+134, b -2.341246678206303e+130, iteration 1000, cost 1.7869580155554598e+266
# m 6.968572953938393e+138, b 1.2036432375870728e+135, iteration 1000, cost 4.722974066281237e+275
# m -3.5825681205306233e+143, b -6.187972659502184e+139, iteration 1000, cost 1.2482936832643687e+285
# m 1.8418110024934943e+148, b 3.181258735064052e+144, iteration 1000, cost 3.299270963189187e+294
# m -9.468815818088766e+152, b -1.635496421252047e+149, iteration 1000, cost 8.720054450710532e+303
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-4-3cd5328f4b6d> in <module>
#      22 y = score.price
#      23
# ---> 24 gradient_descent(x,y)
#
# <ipython-input-4-3cd5328f4b6d> in gradient_descent(x, y)
#      12     for i in range(iterations):
#      13         y_predicted = m_curr*x + b_curr
# ---> 14         cost = (1/n) * sum([val**2 for val in (y - y_predicted)])
#      15         md = -(2/n)*sum(x*(y-y_predicted))
#      16         bd = -(2/n)*sum(y-y_predicted)
#
# <ipython-input-4-3cd5328f4b6d> in <listcomp>(.0)
#      12     for i in range(iterations):
#      13         y_predicted = m_curr*x + b_curr
# ---> 14         cost = (1/n) * sum([val**2 for val in (y - y_predicted)])
#      15         md = -(2/n)*sum(x*(y-y_predicted))
#      16         bd = -(2/n)*sum(y-y_predicted)
#
# OverflowError: (34, 'Result too large')

# %%
score
# Out:
#     area         price
# 0   1000  3.164045e+05
# 1   1500  3.842976e+05
# 2   2300  4.929285e+05
# 3   3540  6.613046e+05
# 4   4120  7.400616e+05
# 5   4560  7.998085e+05
# 6   5490  9.260906e+05
# 7   3460  6.504416e+05
# 8   4750  8.256076e+05
# 9   2300  4.929285e+05
# 10  9000  1.402706e+06
# 11  8600  1.348391e+06
# 12  7100  1.144709e+06
